# %%
# Created on Sept 18, 2025
# Purpose: This file reads the modified file and creates it into several slices

import pandas as pd
import numpy as np
import os as os

# File Paths
modifiedFileLocation = "C:\\Users\\afeen\\Documents\\MBAI\\Business Analytics\\FlaskProjects\\Master Code (BA)\\02MakeSlices\\TorontoCity_traffic_collisions_KPI_Modified.csv"
destinationFolder = "C:\\Users\\afeen\\Documents\\MBAI\\Business Analytics\\FlaskProjects\\Master Code (BA)\\02MakeSlices"

# Read the CSV file
df = pd.read_csv(modifiedFileLocation, low_memory=False)

# extract user-severity slice
UserSeveritySlice = df[[
    # "_id",
    "YEAR_COLLISION_OCCURED",
    "SeverityOfInjury",
    "SeverityOfInjury_Fatal",
    "SeverityOfInjury_Major",
    "SeverityOfInjury_Minor",
    "InvolvementType",
    "AgeOfInvolvedParty",
    "UserInvType_Cyclist",
    "UserInvType_Cyclist_Passenger",
    "UserInvType_Driver___Not_Hit",
    "UserInvType_In_Line_Skater",
    "UserInvType_Moped_Driver",
    "UserInvType_Moped_Passenger",
    "UserInvType_Motorcycle_Driver",
    "UserInvType_Motorcycle_Passenger",
    "UserInvType_Other",
    "UserInvType_Passenger",
    "UserInvType_Pedestrian",
    "UserInvType_Truck_Driver",
    "UserInvType_Wheelchair",
    "UserAgeRange_0_to_4",
    "UserAgeRange_10_to_14",
    "UserAgeRange_15_to_19",
    "UserAgeRange_25_to_29",
    "UserAgeRange_30_to_34",
    "UserAgeRange_35_to_39",
    "UserAgeRange_40_to_44",
    "UserAgeRange_45_to_49",
    "UserAgeRange_5_to_9",
    "UserAgeRange_50_to_54",
    "UserAgeRange_55_to_59",
    "UserAgeRange_60_to_64",
    "UserAgeRange_65_to_69",
    "UserAgeRange_70_to_74",
    "UserAgeRange_75_to_79",
    "UserAgeRange_80_to_84",
    "UserAgeRange_85_to_89",
    "UserAgeRange_90_to_94",
    "UserAgeRange_Over_95",
    "UserAgeRange_unknown"
]]

# extract env-severity slice
EnvSeveritySlice = df[[
    # "_id",
    "YEAR_COLLISION_OCCURED",
    "SeverityOfInjury",
    "SeverityOfInjury_Fatal",
    "SeverityOfInjury_Major",
    "SeverityOfInjury_Minor",
    "LightingCondition",
    "RoadSurfaceCondition",
    "EnvLightingCondition_Dark",
    "EnvLightingCondition_Dark__artificial",
    "EnvLightingCondition_Dawn",
    "EnvLightingCondition_Dawn__artificial",
    "EnvLightingCondition_Daylight__artificial",
    "EnvLightingCondition_Dusk",
    "EnvLightingCondition_Dusk__artificial",
    "EnvLightingCondition_Other",
    "EnvRoadSurfaceCondition_Ice",
    "EnvRoadSurfaceCondition_Loose_Sand_or_Gravel",
    "EnvRoadSurfaceCondition_Loose_Snow",
    "EnvRoadSurfaceCondition_Other",
    "EnvRoadSurfaceCondition_Packed_Snow",
    "EnvRoadSurfaceCondition_Slush",
    "EnvRoadSurfaceCondition_Spilled_liquid",
    "EnvRoadSurfaceCondition_Wet"]]

# # extract time-severity slice
TimeSeveritySlice = df[[
    # "_id",
    "YEAR_COLLISION_OCCURED",
    "SeverityOfInjury",
    "SeverityOfInjury_Fatal",
    "SeverityOfInjury_Major",
    "SeverityOfInjury_Minor",
    "MONTH_NAME_COLLISION_OCCURED",
    "HOUR_COLLISION_OCCURED",
    "PEAKOFFPEAK",
    "TIME_RANGE",
    "SEASON",
   "TimeYear_2007",
   "TimeYear_2008",
   "TimeYear_2009",
   "TimeYear_2010",
   "TimeYear_2011",
   "TimeYear_2012",
   "TimeYear_2013",
   "TimeYear_2014",
   "TimeYear_2015",
   "TimeYear_2016",
   "TimeYear_2017",
   "TimeYear_2018",
   "TimeYear_2019",
   "TimeYear_2020",
   "TimeYear_2021",
   "TimeYear_2022",
   "TimeYear_2023",
   "TimeMonth_April",
   "TimeMonth_August",
   "TimeMonth_December",
   "TimeMonth_February",
   "TimeMonth_July",
   "TimeMonth_June",
   "TimeMonth_March",
   "TimeMonth_May",
   "TimeMonth_November",
   "TimeMonth_October",
   "TimeMonth_September",
   "TimeHour_0",
   "TimeHour_1",
   "TimeHour_2",
   "TimeHour_3",
   "TimeHour_4",
   "TimeHour_5",
   "TimeHour_6",
   "TimeHour_7",
   "TimeHour_8",
   "TimeHour_9",
   "TimeHour_10",
   "TimeHour_11",
   "TimeHour_13",
   "TimeHour_14",
   "TimeHour_15",
   "TimeHour_16",
   "TimeHour_17",
   "TimeHour_18",
   "TimeHour_19",
   "TimeHour_20",
   "TimeHour_21",
   "TimeHour_22",
   "TimeHour_23",
   "TimePeakOffPeak_OFF_PEAK",
   "TimeRange_15_00_to_17_59",
   "TimeRange_18_00_to_20_59",
   "TimeRange_21_00_to_23_59",
   "TimeRange_3_00_to_5_59",
   "TimeRange_6_00_to_8_59",
   "TimeRange_9_00_to_11_59",
   "TimeRange_Midnight_to_2_59",
   "TimeSeason_WINTER"]]

# WRITE TO FILE
UserSeveritySlice.to_csv(os.path.join(destinationFolder, 'UserSeveritySlice.csv'),index=False)
EnvSeveritySlice.to_csv(os.path.join(destinationFolder, 'EnvSeveritySlice.csv'),index=False)
TimeSeveritySlice.to_csv(os.path.join(destinationFolder, 'TimeSeveritySlice.csv'),index=False)

print("Slices Created Successfully")
# Out:
# Slices Created Successfully
